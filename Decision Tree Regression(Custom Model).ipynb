# %%
import pandas as pd
import numpy as np 
from collections import Counter

# %%
class NodeRegression:
    """
    class to grow a regression decision tree
    """
    def __init__(self, Y:list, X:pd.DataFrame, min_samples_split=None, max_depth=None, depth=None, node_type=None, rule=None):
        
        # Saving the Data to the Node
        self.Y = Y
        self.X = X
        
        # Saving the hyper parameters
        self.min_samples_split = min_samples_split if min_samples_split else 20
        self.max_depth = max_depth if max_depth else 5
        
        # Default the current depth
        self.depth = depth if depth else 0
        
        # Extracting all the features
        self.features = list(self.X.columns)
        
        # Type of Node
        self.node_type = node_type if node_type else 'root'
        
        # Rule for splitting
        self.rule = rule if rule else ""
        
        # Getting the mean of Y
        self.ymean = np.mean(Y)
        
        # Getting the residuals 
        self.residuals = self.Y - self.ymean
        
        # Calculating the mse of the node 
        self.mse = self.get_mse(Y, self.ymean)
        
        # Saving the number of observations in the node
        self.n = len(Y)
        
        # Initiating the left and right nodes as empty nodes
        self.left = None
        self.right = None
        
        # Default values for splits
        self.best_feature = None
        self.best_value = None
        
    @staticmethod
    def get_mse(ytrue, yhat) -> float:
        """
        Method to calculate the mean squared error
        """
        # Getting the total no. of samples
        n = len(ytrue)
        
        # getting the residuals
        r = ytrue - yhat
        
        # Squaring the residuals
        r = r ** 2
        
        # Summing
        r = np.sum(r)
        
        # Getting the average and returning
        return r / n
    
    @staticmethod
    def ma(x: np.array, window:int) -> np.array:
        """
        Calculates the moving average of the given list
        """
        return np.convolve(x, np.ones(window), 'valid') / window
    
    
    def best_split(self) -> tuple:
        """
        Given the X features and Y targets calculates the best split
        for a decision tree
        """
        # Creating a dataset for spliting
        df = self.X.copy()
        df['Y'] = self.Y
        
        # Getting the GINI impurity for the base input
        mse_base = self.mse
        
        # Default best feature and split
        best_feature = None
        best_value = None
        
        for feature in self.features:
            
            # Dropping missing values
            Xdf = df.dropna().sort_values(feature)
            
            # Sorting the values and getting the rolling average
            xmeans = self.ma(Xdf[feature].unique(), 2)
            
            for value in xmeans:
                
                # Getting the left and right ys
                left_y = Xdf[Xdf[feature]<value]['Y'].values
                right_y = Xdf[Xdf[feature]>=value]['Y'].values
                
                # Getting the means
                left_mean = np.mean(left_y)
                right_mean = np.mean(right_y)
                
                # getting the left and right residuals
                res_left = left_y - left_mean
                res_right = right_y - right_mean
                
                # Concatenating the residuals
                r = np.concatenate((res_left,res_right), axis=None)
                
                # Calculating the mse
                n = len(r)
                
                r = r ** 2
                
                r = np.sum(r)
                
                mse_split = r / n
                
                # Checking if this is the best split so far
                if mse_split < mse_base:
                    best_feature = feature
                    best_value = value
                    
                    # Setting the best gain to the current one
                    mse_base = mse_split
                    
        return (best_feature, best_value)
    
    
    def grow_tree(self):
        """
        Recursive method to create the decision tree
        """
        
        # Making a df from the data 
        df = self.X.copy()
        df['Y'] = self.Y
        
        # If there is GINI to be gained, we split further 
        if (self.depth < self.max_depth) and (self.n >= self.min_samples_split):
            
            # Getting the best split
            best_feature, best_value = self.best_split()
            
            if best_feature is not None:
                
                # Saving the best split to the current node
                self.best_feature = best_feature
                self.best_value = best_value
                
                # Getting the left and right noodes
                left_df, right_df = df[df[best_feature]<=best_value].copy(), df[df[best_feature]>best_value].copy()
                
                # Creating the left and right Nodes
                left = NodeRegression(left_df['Y'].values.tolist(),
                           left_df[self.features],
                           depth=self.depth + 1,
                           max_depth=self.max_depth,
                           min_samples_split=self.min_samples_split,
                           node_type='left_node',
                           rule=f"{best_feature} <= {round(best_value,3)}")
                
                self.left = left
                self.left.grow_tree()
                
                right = NodeRegression(right_df['Y'].values.tolist(),
                            right_df[self.features],
                            max_depth=self.max_depth,
                            min_samples_split=self.min_samples_split,
                            node_type='right_node',
                            rule=f"{best_feature} > {round(best_value,3)}")
                
                self.right = right
                self.right.grow_tree()
                
    def print_info(self, width=4):
        """
        Method to print the information about the tree
        """
        # Defining the number of spaces
        const = int(self.depth * width ** 1.5)
        spaces = "-" * const
        
        
        if self.node_type == "root":
            
            print("Root")
            
        else:
            
            print(f"|{spaces} Split rule: {self.rule}")
            
        print(f"{' ' * const} | MSE of the node: {round(self.mse, 2)}")
        print(f"{' ' * const} | Count of observations in node: {self.n}")
        print(f"{' ' * const} | Prediction of node: {round(self.ymean, 3)}")
        
        
    def print_tree(self):
        """
        Prints the whole tree from the current node to the bottom
        """
        self.print_info()
        
        if self.left is not None:
            self.left.print_tree()
            
        if self.right is not None:
            self.right.print_tree()

# %%
d = pd.read_csv("https://raw.githubusercontent.com/Eligijus112/decision-tree-python/main/data/regression/auto-mpg.csv")

# %%
# Subsetting
d = d[d['horsepower']!='?']

# %%
# Constructing the X and Y matrices
features = ['horsepower', 'weight', 'acceleration']

# %%
for ft in features:
    d[ft] = pd.to_numeric(d[ft])

# %%
X = d[features]
Y = d['mpg'].values.tolist()

# %%
# Initiating the Node
root = NodeRegression(Y, X, max_depth=3, min_samples_split=3)

# %%
# Growing the tree
root.grow_tree()

# %%
# Printing tree 
root.print_tree()
# Out:
# Root
#  | MSE of the node: 60.76
#  | Count of observations in node: 392
#  | Prediction of node: 23.446
# |-------- Split rule: weight <= 2764.5
#          | MSE of the node: 32.65
#          | Count of observations in node: 191
#          | Prediction of node: 29.42
# |---------------- Split rule: horsepower <= 70.5
#                  | MSE of the node: 25.84
#                  | Count of observations in node: 69
#                  | Prediction of node: 33.68
# |------------------------ Split rule: acceleration <= 23.6
#                          | MSE of the node: 23.52
#                          | Count of observations in node: 67
#                          | Prediction of node: 33.381
# | Split rule: acceleration > 23.6
#  | MSE of the node: 0.09
#  | Count of observations in node: 2
#  | Prediction of node: 43.7
# | Split rule: horsepower > 70.5
#  | MSE of the node: 20.43
#  | Count of observations in node: 122
#  | Prediction of node: 27.011
# |-------- Split rule: horsepower <= 84.5
#          | MSE of the node: 17.65
#          | Count of observations in node: 53
#          | Prediction of node: 29.03
# |---------------- Split rule: acceleration <= 15.4
#                  | MSE of the node: 13.94
#                  | Count of observations in node: 25
#                  | Prediction of node: 31.132
# |------------------------ Split rule: weight <= 2475.0
#                          | MSE of the node: 13.48
#                          | Count of observations in node: 23
#                          | Prediction of node: 31.496
# | Split rule: weight > 2475.0
#  | MSE of the node: 0.2
#  | Count of observations in node: 2
#  | Prediction of node: 26.95
# | Split rule: acceleration > 15.4
#  | MSE of the node: 13.5
#  | Count of observations in node: 28
#  | Prediction of node: 27.154
# |-------- Split rule: weight <= 2091.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 33.5
# | Split rule: weight > 2091.5
#  | MSE of the node: 12.45
#  | Count of observations in node: 27
#  | Prediction of node: 26.919
# |-------- Split rule: acceleration <= 19.45
#          | MSE of the node: 11.53
#          | Count of observations in node: 26
#          | Prediction of node: 27.146
# |---------------- Split rule: acceleration <= 15.6
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 2
#                  | Prediction of node: 24.0
# | Split rule: acceleration > 15.6
#  | MSE of the node: 11.6
#  | Count of observations in node: 24
#  | Prediction of node: 27.408
# |-------- Split rule: acceleration <= 16.2
#          | MSE of the node: 7.07
#          | Count of observations in node: 4
#          | Prediction of node: 29.875
# |---------------- Split rule: horsepower <= 81.0
#                  | MSE of the node: 7.02
#                  | Count of observations in node: 2
#                  | Prediction of node: 31.65
# | Split rule: horsepower > 81.0
#  | MSE of the node: 0.81
#  | Count of observations in node: 2
#  | Prediction of node: 28.1
# | Split rule: acceleration > 16.2
#  | MSE of the node: 11.05
#  | Count of observations in node: 20
#  | Prediction of node: 26.915
# |-------- Split rule: horsepower <= 75.5
#          | MSE of the node: 13.36
#          | Count of observations in node: 9
#          | Prediction of node: 28.189
# |---------------- Split rule: acceleration <= 18.65
#                  | MSE of the node: 9.64
#                  | Count of observations in node: 8
#                  | Prediction of node: 28.962
# |------------------------ Split rule: weight <= 2277.5
#                          | MSE of the node: 1.56
#                          | Count of observations in node: 3
#                          | Prediction of node: 26.333
# | Split rule: weight > 2277.5
#  | MSE of the node: 7.86
#  | Count of observations in node: 5
#  | Prediction of node: 30.54
# |-------- Split rule: weight <= 2446.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 2
#          | Prediction of node: 32.4
# | Split rule: weight > 2446.0
#  | MSE of the node: 9.26
#  | Count of observations in node: 3
#  | Prediction of node: 29.3
# |-------- Split rule: acceleration <= 17.25
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 25.0
# | Split rule: acceleration > 17.25
#  | MSE of the node: 0.02
#  | Count of observations in node: 2
#  | Prediction of node: 31.45
# | Split rule: acceleration > 18.65
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 22.0
# | Split rule: horsepower > 75.5
#  | MSE of the node: 6.74
#  | Count of observations in node: 11
#  | Prediction of node: 25.873
# |-------- Split rule: acceleration <= 18.55
#          | MSE of the node: 4.17
#          | Count of observations in node: 9
#          | Prediction of node: 25.067
# |---------------- Split rule: acceleration <= 16.7
#                  | MSE of the node: 1.68
#                  | Count of observations in node: 3
#                  | Prediction of node: 27.2
# |------------------------ Split rule: weight <= 2335.0
#                          | MSE of the node: 0.0
#                          | Count of observations in node: 1
#                          | Prediction of node: 29.0
# | Split rule: weight > 2335.0
#  | MSE of the node: 0.09
#  | Count of observations in node: 2
#  | Prediction of node: 26.3
# | Split rule: acceleration > 16.7
#  | MSE of the node: 2.0
#  | Count of observations in node: 6
#  | Prediction of node: 24.0
# |-------- Split rule: weight <= 2383.0
#          | MSE of the node: 0.22
#          | Count of observations in node: 3
#          | Prediction of node: 25.333
# |---------------- Split rule: horsepower <= 79.5
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 26.0
# | Split rule: horsepower > 79.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 25.0
# | Split rule: weight > 2383.0
#  | MSE of the node: 0.22
#  | Count of observations in node: 3
#  | Prediction of node: 22.667
# |-------- Split rule: horsepower <= 77.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 22.0
# | Split rule: horsepower > 77.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 23.0
# | Split rule: acceleration > 18.55
#  | MSE of the node: 2.25
#  | Count of observations in node: 2
#  | Prediction of node: 29.5
# | Split rule: acceleration > 19.45
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 21.0
# | Split rule: horsepower > 84.5
#  | MSE of the node: 17.03
#  | Count of observations in node: 69
#  | Prediction of node: 25.459
# |-------- Split rule: horsepower <= 93.5
#          | MSE of the node: 21.11
#          | Count of observations in node: 39
#          | Prediction of node: 26.297
# |---------------- Split rule: acceleration <= 18.25
#                  | MSE of the node: 19.95
#                  | Count of observations in node: 34
#                  | Prediction of node: 26.812
# |------------------------ Split rule: weight <= 2578.5
#                          | MSE of the node: 24.51
#                          | Count of observations in node: 21
#                          | Prediction of node: 27.833
# | Split rule: weight > 2578.5
#  | MSE of the node: 8.19
#  | Count of observations in node: 13
#  | Prediction of node: 25.162
# |-------- Split rule: weight <= 2659.0
#          | MSE of the node: 6.71
#          | Count of observations in node: 5
#          | Prediction of node: 22.76
# |---------------- Split rule: horsepower <= 91.5
#                  | MSE of the node: 0.22
#                  | Count of observations in node: 3
#                  | Prediction of node: 20.667
# |------------------------ Split rule: horsepower <= 90.5
#                          | MSE of the node: 0.0
#                          | Count of observations in node: 2
#                          | Prediction of node: 21.0
# | Split rule: horsepower > 90.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 20.0
# | Split rule: horsepower > 91.5
#  | MSE of the node: 0.01
#  | Count of observations in node: 2
#  | Prediction of node: 25.9
# | Split rule: weight > 2659.0
#  | MSE of the node: 3.25
#  | Count of observations in node: 8
#  | Prediction of node: 26.662
# |-------- Split rule: horsepower <= 89.5
#          | MSE of the node: 0.13
#          | Count of observations in node: 4
#          | Prediction of node: 25.025
# |---------------- Split rule: acceleration <= 15.9
#                  | MSE of the node: 0.04
#                  | Count of observations in node: 2
#                  | Prediction of node: 25.3
# | Split rule: acceleration > 15.9
#  | MSE of the node: 0.06
#  | Count of observations in node: 2
#  | Prediction of node: 24.75
# | Split rule: horsepower > 89.5
#  | MSE of the node: 1.01
#  | Count of observations in node: 4
#  | Prediction of node: 28.3
# |-------- Split rule: acceleration <= 15.75
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 29.8
# | Split rule: acceleration > 15.75
#  | MSE of the node: 0.35
#  | Count of observations in node: 3
#  | Prediction of node: 27.8
# |-------- Split rule: weight <= 2706.5
#          | MSE of the node: 0.04
#          | Count of observations in node: 2
#          | Prediction of node: 28.2
# | Split rule: weight > 2706.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 27.0
# | Split rule: acceleration > 18.25
#  | MSE of the node: 14.96
#  | Count of observations in node: 5
#  | Prediction of node: 22.8
# |-------- Split rule: weight <= 2506.5
#          | MSE of the node: 0.22
#          | Count of observations in node: 3
#          | Prediction of node: 19.667
# |---------------- Split rule: horsepower <= 86.5
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 19.0
# | Split rule: horsepower > 86.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 20.0
# | Split rule: weight > 2506.5
#  | MSE of the node: 0.25
#  | Count of observations in node: 2
#  | Prediction of node: 27.5
# | Split rule: horsepower > 93.5
#  | MSE of the node: 9.62
#  | Count of observations in node: 30
#  | Prediction of node: 24.37
# |-------- Split rule: horsepower <= 111.5
#          | MSE of the node: 9.88
#          | Count of observations in node: 26
#          | Prediction of node: 24.019
# |---------------- Split rule: acceleration <= 13.7
#                  | MSE of the node: 3.88
#                  | Count of observations in node: 7
#                  | Prediction of node: 21.743
# |------------------------ Split rule: acceleration <= 12.7
#                          | MSE of the node: 0.01
#                          | Count of observations in node: 2
#                          | Prediction of node: 23.6
# | Split rule: acceleration > 12.7
#  | MSE of the node: 3.5
#  | Count of observations in node: 5
#  | Prediction of node: 21.0
# |-------- Split rule: horsepower <= 96.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 24.0
# | Split rule: horsepower > 96.5
#  | MSE of the node: 1.56
#  | Count of observations in node: 4
#  | Prediction of node: 20.25
# |-------- Split rule: horsepower <= 105.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 2
#          | Prediction of node: 19.0
# | Split rule: horsepower > 105.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 21.5
# | Split rule: acceleration > 13.7
#  | MSE of the node: 9.48
#  | Count of observations in node: 19
#  | Prediction of node: 24.858
# |-------- Split rule: acceleration <= 13.95
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 32.0
# | Split rule: acceleration > 13.95
#  | MSE of the node: 7.01
#  | Count of observations in node: 18
#  | Prediction of node: 24.461
# |-------- Split rule: weight <= 2552.5
#          | MSE of the node: 2.81
#          | Count of observations in node: 13
#          | Prediction of node: 23.823
# |---------------- Split rule: weight <= 2377.0
#                  | MSE of the node: 1.17
#                  | Count of observations in node: 6
#                  | Prediction of node: 25.117
# |------------------------ Split rule: horsepower <= 96.5
#                          | MSE of the node: 0.36
#                          | Count of observations in node: 5
#                          | Prediction of node: 24.7
# | Split rule: horsepower > 96.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 27.2
# | Split rule: weight > 2377.0
#  | MSE of the node: 1.55
#  | Count of observations in node: 7
#  | Prediction of node: 22.714
# |-------- Split rule: acceleration <= 14.85
#          | MSE of the node: 0.85
#          | Count of observations in node: 3
#          | Prediction of node: 21.7
# |---------------- Split rule: horsepower <= 102.0
#                  | MSE of the node: 0.9
#                  | Count of observations in node: 2
#                  | Prediction of node: 22.05
# | Split rule: horsepower > 102.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 21.0
# | Split rule: acceleration > 14.85
#  | MSE of the node: 0.73
#  | Count of observations in node: 4
#  | Prediction of node: 23.475
# |-------- Split rule: horsepower <= 95.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 22.0
# | Split rule: horsepower > 95.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 3
#  | Prediction of node: 23.967
# |-------- Split rule: weight <= 2447.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 23.9
# | Split rule: weight > 2447.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 24.0
# | Split rule: weight > 2552.5
#  | MSE of the node: 14.13
#  | Count of observations in node: 5
#  | Prediction of node: 26.12
# |-------- Split rule: weight <= 2637.5
#          | MSE of the node: 7.29
#          | Count of observations in node: 2
#          | Prediction of node: 30.2
# | Split rule: weight > 2637.5
#  | MSE of the node: 0.19
#  | Count of observations in node: 3
#  | Prediction of node: 23.4
# |-------- Split rule: horsepower <= 107.5
#          | MSE of the node: 0.01
#          | Count of observations in node: 2
#          | Prediction of node: 23.1
# | Split rule: horsepower > 107.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 24.0
# | Split rule: horsepower > 111.5
#  | MSE of the node: 1.95
#  | Count of observations in node: 4
#  | Prediction of node: 26.65
# |-------- Split rule: acceleration <= 11.9
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 28.8
# | Split rule: acceleration > 11.9
#  | MSE of the node: 0.54
#  | Count of observations in node: 3
#  | Prediction of node: 25.933
# |-------- Split rule: acceleration <= 13.2
#          | MSE of the node: 0.16
#          | Count of observations in node: 2
#          | Prediction of node: 26.4
# | Split rule: acceleration > 13.2
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 25.0
# | Split rule: weight > 2764.5
#  | MSE of the node: 21.34
#  | Count of observations in node: 201
#  | Prediction of node: 17.769
# |-------- Split rule: horsepower <= 127.0
#          | MSE of the node: 16.76
#          | Count of observations in node: 103
#          | Prediction of node: 20.669
# |---------------- Split rule: horsepower <= 71.5
#                  | MSE of the node: 14.83
#                  | Count of observations in node: 3
#                  | Prediction of node: 31.2
# |------------------------ Split rule: weight <= 3070.0
#                          | MSE of the node: 0.0
#                          | Count of observations in node: 1
#                          | Prediction of node: 36.4
# | Split rule: weight > 3070.0
#  | MSE of the node: 1.96
#  | Count of observations in node: 2
#  | Prediction of node: 28.6
# | Split rule: horsepower > 71.5
#  | MSE of the node: 13.39
#  | Count of observations in node: 100
#  | Prediction of node: 20.353
# |-------- Split rule: weight <= 3018.0
#          | MSE of the node: 15.54
#          | Count of observations in node: 35
#          | Prediction of node: 22.32
# |---------------- Split rule: weight <= 3013.5
#                  | MSE of the node: 8.55
#                  | Count of observations in node: 34
#                  | Prediction of node: 21.859
# |------------------------ Split rule: horsepower <= 96.0
#                          | MSE of the node: 4.93
#                          | Count of observations in node: 14
#                          | Prediction of node: 23.414
# | Split rule: horsepower > 96.0
#  | MSE of the node: 8.2
#  | Count of observations in node: 20
#  | Prediction of node: 20.77
# |-------- Split rule: acceleration <= 14.45
#          | MSE of the node: 13.03
#          | Count of observations in node: 5
#          | Prediction of node: 23.1
# |---------------- Split rule: weight <= 2946.0
#                  | MSE of the node: 8.16
#                  | Count of observations in node: 4
#                  | Prediction of node: 24.375
# |------------------------ Split rule: horsepower <= 121.0
#                          | MSE of the node: 2.38
#                          | Count of observations in node: 3
#                          | Prediction of node: 25.833
# | Split rule: horsepower > 121.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 20.0
# | Split rule: weight > 2946.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 18.0
# | Split rule: acceleration > 14.45
#  | MSE of the node: 4.18
#  | Count of observations in node: 15
#  | Prediction of node: 19.993
# |-------- Split rule: acceleration <= 16.2
#          | MSE of the node: 2.56
#          | Count of observations in node: 14
#          | Prediction of node: 19.636
# |---------------- Split rule: weight <= 2792.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 2
#                  | Prediction of node: 18.0
# | Split rule: weight > 2792.0
#  | MSE of the node: 2.46
#  | Count of observations in node: 12
#  | Prediction of node: 19.908
# |-------- Split rule: weight <= 2851.5
#          | MSE of the node: 0.49
#          | Count of observations in node: 4
#          | Prediction of node: 21.475
# |---------------- Split rule: acceleration <= 15.8
#                  | MSE of the node: 0.04
#                  | Count of observations in node: 3
#                  | Prediction of node: 21.867
# |------------------------ Split rule: horsepower <= 113.5
#                          | MSE of the node: 0.0
#                          | Count of observations in node: 2
#                          | Prediction of node: 22.0
# | Split rule: horsepower > 113.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 21.6
# | Split rule: acceleration > 15.8
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 20.3
# | Split rule: weight > 2851.5
#  | MSE of the node: 1.61
#  | Count of observations in node: 8
#  | Prediction of node: 19.125
# |-------- Split rule: horsepower <= 99.0
#          | MSE of the node: 4.0
#          | Count of observations in node: 2
#          | Prediction of node: 20.0
# | Split rule: horsepower > 99.0
#  | MSE of the node: 0.47
#  | Count of observations in node: 6
#  | Prediction of node: 18.833
# |-------- Split rule: weight <= 2931.5
#          | MSE of the node: 0.19
#          | Count of observations in node: 4
#          | Prediction of node: 19.25
# |---------------- Split rule: horsepower <= 104.0
#                  | MSE of the node: 0.25
#                  | Count of observations in node: 2
#                  | Prediction of node: 19.5
# | Split rule: horsepower > 104.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 19.0
# | Split rule: weight > 2931.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 18.0
# | Split rule: acceleration > 16.2
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 25.0
# | Split rule: weight > 3013.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 38.0
# | Split rule: weight > 3018.0
#  | MSE of the node: 9.04
#  | Count of observations in node: 65
#  | Prediction of node: 19.294
# |-------- Split rule: acceleration <= 19.55
#          | MSE of the node: 5.03
#          | Count of observations in node: 57
#          | Prediction of node: 18.895
# |---------------- Split rule: weight <= 3727.5
#                  | MSE of the node: 4.33
#                  | Count of observations in node: 49
#                  | Prediction of node: 19.184
# |------------------------ Split rule: weight <= 3688.0
#                          | MSE of the node: 3.25
#                          | Count of observations in node: 48
#                          | Prediction of node: 19.029
# | Split rule: weight > 3688.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 26.6
# | Split rule: weight > 3727.5
#  | MSE of the node: 5.67
#  | Count of observations in node: 8
#  | Prediction of node: 17.125
# |-------- Split rule: horsepower <= 122.5
#          | MSE of the node: 0.85
#          | Count of observations in node: 7
#          | Prediction of node: 16.286
# |---------------- Split rule: horsepower <= 97.5
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 18.0
# | Split rule: horsepower > 97.5
#  | MSE of the node: 0.42
#  | Count of observations in node: 6
#  | Prediction of node: 16.0
# |-------- Split rule: weight <= 3755.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 15.0
# | Split rule: weight > 3755.5
#  | MSE of the node: 0.26
#  | Count of observations in node: 5
#  | Prediction of node: 16.2
# |-------- Split rule: weight <= 4011.0
#          | MSE of the node: 0.12
#          | Count of observations in node: 4
#          | Prediction of node: 16.0
# |---------------- Split rule: weight <= 3929.5
#                  | MSE of the node: 0.06
#                  | Count of observations in node: 3
#                  | Prediction of node: 16.167
# |------------------------ Split rule: horsepower <= 112.5
#                          | MSE of the node: 0.0
#                          | Count of observations in node: 2
#                          | Prediction of node: 16.0
# | Split rule: horsepower > 112.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 16.5
# | Split rule: weight > 3929.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 15.5
# | Split rule: weight > 4011.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 17.0
# | Split rule: horsepower > 122.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 23.0
# | Split rule: acceleration > 19.55
#  | MSE of the node: 28.36
#  | Count of observations in node: 8
#  | Prediction of node: 22.138
# |-------- Split rule: acceleration <= 20.7
#          | MSE of the node: 4.68
#          | Count of observations in node: 3
#          | Prediction of node: 28.067
# |---------------- Split rule: weight <= 3380.0
#                  | MSE of the node: 1.69
#                  | Count of observations in node: 2
#                  | Prediction of node: 29.4
# | Split rule: weight > 3380.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 25.4
# | Split rule: acceleration > 20.7
#  | MSE of the node: 8.83
#  | Count of observations in node: 5
#  | Prediction of node: 18.58
# |-------- Split rule: acceleration <= 22.05
#          | MSE of the node: 2.19
#          | Count of observations in node: 4
#          | Prediction of node: 17.25
# |---------------- Split rule: horsepower <= 75.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 15.0
# | Split rule: horsepower > 75.0
#  | MSE of the node: 0.67
#  | Count of observations in node: 3
#  | Prediction of node: 18.0
# |-------- Split rule: horsepower <= 99.0
#          | MSE of the node: 0.25
#          | Count of observations in node: 2
#          | Prediction of node: 18.5
# | Split rule: horsepower > 99.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 17.0
# | Split rule: acceleration > 22.05
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 23.9
# | Split rule: horsepower > 127.0
#  | MSE of the node: 8.02
#  | Count of observations in node: 98
#  | Prediction of node: 14.721
# |-------- Split rule: weight <= 2998.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 32.7
# | Split rule: weight > 2998.0
#  | MSE of the node: 4.74
#  | Count of observations in node: 97
#  | Prediction of node: 14.536
# |-------- Split rule: weight <= 4361.5
#          | MSE of the node: 3.63
#          | Count of observations in node: 66
#          | Prediction of node: 15.326
# |---------------- Split rule: weight <= 3589.5
#                  | MSE of the node: 4.03
#                  | Count of observations in node: 13
#                  | Prediction of node: 16.723
# |------------------------ Split rule: weight <= 3187.0
#                          | MSE of the node: 0.25
#                          | Count of observations in node: 2
#                          | Prediction of node: 13.5
# | Split rule: weight > 3187.0
#  | MSE of the node: 2.49
#  | Count of observations in node: 11
#  | Prediction of node: 17.309
# |-------- Split rule: weight <= 3566.5
#          | MSE of the node: 1.82
#          | Count of observations in node: 10
#          | Prediction of node: 17.02
# |---------------- Split rule: horsepower <= 147.5
#                  | MSE of the node: 1.05
#                  | Count of observations in node: 5
#                  | Prediction of node: 17.7
# |------------------------ Split rule: acceleration <= 14.5
#                          | MSE of the node: 0.61
#                          | Count of observations in node: 4
#                          | Prediction of node: 18.075
# | Split rule: acceleration > 14.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 16.2
# | Split rule: horsepower > 147.5
#  | MSE of the node: 1.66
#  | Count of observations in node: 5
#  | Prediction of node: 16.34
# |-------- Split rule: weight <= 3434.5
#          | MSE of the node: 0.25
#          | Count of observations in node: 2
#          | Prediction of node: 15.5
# | Split rule: weight > 3434.5
#  | MSE of the node: 1.82
#  | Count of observations in node: 3
#  | Prediction of node: 16.9
# |-------- Split rule: horsepower <= 167.5
#          | MSE of the node: 0.02
#          | Count of observations in node: 2
#          | Prediction of node: 17.85
# | Split rule: horsepower > 167.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 15.0
# | Split rule: weight > 3566.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 20.2
# | Split rule: weight > 3589.5
#  | MSE of the node: 2.93
#  | Count of observations in node: 53
#  | Prediction of node: 14.983
# |-------- Split rule: horsepower <= 143.5
#          | MSE of the node: 4.07
#          | Count of observations in node: 14
#          | Prediction of node: 15.943
# |---------------- Split rule: weight <= 3855.0
#                  | MSE of the node: 0.79
#                  | Count of observations in node: 4
#                  | Prediction of node: 18.05
# |------------------------ Split rule: horsepower <= 137.5
#                          | MSE of the node: 0.24
#                          | Count of observations in node: 3
#                          | Prediction of node: 17.6
# | Split rule: horsepower > 137.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 19.4
# | Split rule: weight > 3855.0
#  | MSE of the node: 2.89
#  | Count of observations in node: 10
#  | Prediction of node: 15.1
# |-------- Split rule: acceleration <= 13.85
#          | MSE of the node: 0.22
#          | Count of observations in node: 3
#          | Prediction of node: 17.167
# |---------------- Split rule: horsepower <= 139.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 16.5
# | Split rule: horsepower > 139.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 17.5
# | Split rule: acceleration > 13.85
#  | MSE of the node: 1.42
#  | Count of observations in node: 7
#  | Prediction of node: 14.214
# |-------- Split rule: acceleration <= 14.95
#          | MSE of the node: 1.16
#          | Count of observations in node: 5
#          | Prediction of node: 14.7
# |---------------- Split rule: horsepower <= 138.5
#                  | MSE of the node: 0.67
#                  | Count of observations in node: 3
#                  | Prediction of node: 14.0
# |------------------------ Split rule: weight <= 4196.5
#                          | MSE of the node: 0.25
#                          | Count of observations in node: 2
#                          | Prediction of node: 13.5
# | Split rule: weight > 4196.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 15.0
# | Split rule: horsepower > 138.5
#  | MSE of the node: 0.06
#  | Count of observations in node: 2
#  | Prediction of node: 15.75
# | Split rule: acceleration > 14.95
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 13.0
# | Split rule: horsepower > 143.5
#  | MSE of the node: 2.08
#  | Count of observations in node: 39
#  | Prediction of node: 14.638
# |-------- Split rule: weight <= 3668.0
#          | MSE of the node: 2.25
#          | Count of observations in node: 2
#          | Prediction of node: 12.5
# | Split rule: weight > 3668.0
#  | MSE of the node: 1.81
#  | Count of observations in node: 37
#  | Prediction of node: 14.754
# |-------- Split rule: weight <= 4357.0
#          | MSE of the node: 1.73
#          | Count of observations in node: 36
#          | Prediction of node: 14.694
# |---------------- Split rule: weight <= 3964.0
#                  | MSE of the node: 2.95
#                  | Count of observations in node: 12
#                  | Prediction of node: 15.083
# |------------------------ Split rule: acceleration <= 13.1
#                          | MSE of the node: 2.5
#                          | Count of observations in node: 10
#                          | Prediction of node: 15.5
# | Split rule: acceleration > 13.1
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 13.0
# | Split rule: weight > 3964.0
#  | MSE of the node: 1.0
#  | Count of observations in node: 24
#  | Prediction of node: 14.5
# |-------- Split rule: weight <= 4132.0
#          | MSE of the node: 0.49
#          | Count of observations in node: 7
#          | Prediction of node: 13.714
# |---------------- Split rule: weight <= 4066.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 2
#                  | Prediction of node: 13.0
# | Split rule: weight > 4066.0
#  | MSE of the node: 0.4
#  | Count of observations in node: 5
#  | Prediction of node: 14.0
# |-------- Split rule: horsepower <= 147.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 15.0
# | Split rule: horsepower > 147.5
#  | MSE of the node: 0.19
#  | Count of observations in node: 4
#  | Prediction of node: 13.75
# |-------- Split rule: horsepower <= 164.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 3
#          | Prediction of node: 14.0
# | Split rule: horsepower > 164.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 13.0
# | Split rule: weight > 4132.0
#  | MSE of the node: 0.85
#  | Count of observations in node: 17
#  | Prediction of node: 14.824
# |-------- Split rule: horsepower <= 149.5
#          | MSE of the node: 0.06
#          | Count of observations in node: 2
#          | Prediction of node: 15.75
# | Split rule: horsepower > 149.5
#  | MSE of the node: 0.83
#  | Count of observations in node: 15
#  | Prediction of node: 14.7
# |-------- Split rule: horsepower <= 167.5
#          | MSE of the node: 0.68
#          | Count of observations in node: 8
#          | Prediction of node: 14.312
# |---------------- Split rule: weight <= 4199.5
#                  | MSE of the node: 0.67
#                  | Count of observations in node: 3
#                  | Prediction of node: 15.0
# |------------------------ Split rule: horsepower <= 151.5
#                          | MSE of the node: 0.25
#                          | Count of observations in node: 2
#                          | Prediction of node: 15.5
# | Split rule: horsepower > 151.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 14.0
# | Split rule: weight > 4199.5
#  | MSE of the node: 0.24
#  | Count of observations in node: 5
#  | Prediction of node: 13.9
# |-------- Split rule: weight <= 4265.5
#          | MSE of the node: 0.05
#          | Count of observations in node: 4
#          | Prediction of node: 14.125
# |---------------- Split rule: horsepower <= 151.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 2
#                  | Prediction of node: 14.0
# | Split rule: horsepower > 151.0
#  | MSE of the node: 0.06
#  | Count of observations in node: 2
#  | Prediction of node: 14.25
# | Split rule: weight > 4265.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 13.0
# | Split rule: horsepower > 167.5
#  | MSE of the node: 0.62
#  | Count of observations in node: 7
#  | Prediction of node: 15.143
# |-------- Split rule: acceleration <= 9.25
#          | MSE of the node: 0.0
#          | Count of observations in node: 2
#          | Prediction of node: 14.0
# | Split rule: acceleration > 9.25
#  | MSE of the node: 0.14
#  | Count of observations in node: 5
#  | Prediction of node: 15.6
# |-------- Split rule: weight <= 4333.0
#          | MSE of the node: 0.06
#          | Count of observations in node: 4
#          | Prediction of node: 15.75
# |---------------- Split rule: acceleration <= 11.25
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 2
#                  | Prediction of node: 16.0
# | Split rule: acceleration > 11.25
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 15.5
# | Split rule: weight > 4333.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 15.0
# | Split rule: weight > 4357.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 16.9
# | Split rule: weight > 4361.5
#  | MSE of the node: 2.95
#  | Count of observations in node: 31
#  | Prediction of node: 12.855
# |-------- Split rule: horsepower <= 191.5
#          | MSE of the node: 1.92
#          | Count of observations in node: 22
#          | Prediction of node: 13.477
# |---------------- Split rule: weight <= 4683.5
#                  | MSE of the node: 1.76
#                  | Count of observations in node: 16
#                  | Prediction of node: 13.906
# |------------------------ Split rule: weight <= 4662.5
#                          | MSE of the node: 1.56
#                          | Count of observations in node: 15
#                          | Prediction of node: 13.767
# | Split rule: weight > 4662.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 16.0
# | Split rule: weight > 4683.5
#  | MSE of the node: 0.56
#  | Count of observations in node: 6
#  | Prediction of node: 12.333
# |-------- Split rule: weight <= 4826.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 2
#          | Prediction of node: 13.0
# | Split rule: weight > 4826.0
#  | MSE of the node: 0.5
#  | Count of observations in node: 4
#  | Prediction of node: 12.0
# |-------- Split rule: horsepower <= 158.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 11.0
# | Split rule: horsepower > 158.5
#  | MSE of the node: 0.22
#  | Count of observations in node: 3
#  | Prediction of node: 12.333
# |-------- Split rule: weight <= 5047.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 2
#          | Prediction of node: 12.0
# | Split rule: weight > 5047.5
#  | MSE of the node: 0.0
#  | Count of observations in node: 1
#  | Prediction of node: 13.0
# | Split rule: horsepower > 191.5
#  | MSE of the node: 2.22
#  | Count of observations in node: 9
#  | Prediction of node: 11.333
# |-------- Split rule: acceleration <= 12.5
#          | MSE of the node: 1.04
#          | Count of observations in node: 5
#          | Prediction of node: 12.4
# |---------------- Split rule: weight <= 4529.0
#                  | MSE of the node: 0.0
#                  | Count of observations in node: 1
#                  | Prediction of node: 14.0
# | Split rule: weight > 4529.0
#  | MSE of the node: 0.5
#  | Count of observations in node: 4
#  | Prediction of node: 12.0
# |-------- Split rule: weight <= 4684.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 11.0
# | Split rule: weight > 4684.0
#  | MSE of the node: 0.22
#  | Count of observations in node: 3
#  | Prediction of node: 12.333
# |-------- Split rule: weight <= 4843.0
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 13.0
# | Split rule: weight > 4843.0
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 12.0
# | Split rule: acceleration > 12.5
#  | MSE of the node: 0.5
#  | Count of observations in node: 4
#  | Prediction of node: 10.0
# |-------- Split rule: horsepower <= 196.5
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 9.0
# | Split rule: horsepower > 196.5
#  | MSE of the node: 0.22
#  | Count of observations in node: 3
#  | Prediction of node: 10.333
# |-------- Split rule: acceleration <= 13.75
#          | MSE of the node: 0.0
#          | Count of observations in node: 1
#          | Prediction of node: 11.0
# | Split rule: acceleration > 13.75
#  | MSE of the node: 0.0
#  | Count of observations in node: 2
#  | Prediction of node: 10.0
